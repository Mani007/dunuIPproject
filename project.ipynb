# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mydf = pd.read_csv('dataset.csv')
mydf
# Out:
#    S.No. States/ Indicators  Literacy Rate - ST  Literacy Rate - All  \
# 0      1       Chhattisgarh                59.1                 70.3
# 1      2          Jharkhand                57.1                 66.4
# 2      3     Madhya Pradesh                50.6                 69.3
# 3      4          Rajasthan                52.8                 66.1
# 4      5             Odisha                52.2                 72.9
# 5      6        Maharashtra                65.7                 82.3
# 6      7            Gujarat                62.5                 78.0
# 7      8     Andhra Pradesh                48.8                 67.4
# 8      9        West Bengal                57.9                 76.3
# 9     10          Karnataka                62.1                 75.4
#
#    Sex-Ratio - ST  Sex-Ratio - All  \
# 0            1020              991
# 1            1003              948
# 2             984              931
# 3             948              928
# ...

# %%
plt.plot(mydf['States/ Indicators'], mydf['Gross Enrollment Ratio (GER) at Secondary Level 2021-22 - All'], marker='o',markeredgecolor='b')
plt.title('State wise Gross enrollment Ratio (GER) at Secondary Level for year 2021-22')
plt.xlabel('States')
plt.ylabel('Gross Enrollment Ratio (GER) at Secondary Level')
fig = plt.gcf()  # get current figure
fig.set_size_inches(14, 6)  # set new size
fig.show()
# Out:
# C:\Users\Mohnish\AppData\Local\Temp\ipykernel_15648\1119702636.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
plt.bar(mydf['States/ Indicators'], mydf['Literacy Rate - All'], color='green')
plt.title('State wise Literacy Rate - All category ')
plt.xlabel('States')
plt.ylabel('Literacy Rate - All')
fig = plt.gcf()  # get current figure
fig.set_size_inches(14, 6)  # set new size
fig.show()
# Out:
# C:\Users\Mohnish\AppData\Local\Temp\ipykernel_15648\274561685.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
plt.barh(mydf['States/ Indicators'], mydf['Sex-Ratio - All'], color='purple')
plt.title('State wise Sex ratio - All category ')
plt.xlabel('Sex-Ratio - All')
plt.ylabel('States')
fig = plt.gcf()  # get current figure
fig.set_size_inches(14, 6)  # set new size
fig.show()
# Out:
# C:\Users\Mohnish\AppData\Local\Temp\ipykernel_15648\1096066156.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
x_ticks = np.arange(len(mydf['Literacy Rate - All']))
#x_ticks = mydf['States/ Indicators']
mywidth=0.25
#plt.xticks(x_ticks+10/2,mydf['States/ Indicators'])

plt.bar(x_ticks,mydf['Literacy Rate - All'],width=mywidth,label='Literacy Rate - All',color='green')
#plt.bar(x_ticks,mydf['Sex-Ratio - All'],width=mywidth,label='Sex-Ratio - All',color='green')
plt.bar(x_ticks+mywidth,mydf['Gross Enrollment Ratio (GER) at Secondary Level 2021-22 - All'],width=mywidth,label='(GER)2021-22 - All',color='purple')
plt.title('State wise Literacy rate and Gross enrollment - All category ')
plt.xlabel('States')
plt.ylabel('Values')
plt.legend()
plt.show()
