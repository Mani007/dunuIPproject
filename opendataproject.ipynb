# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Top Indian Places to Visit.csv')
dataset
# Out:
#      Unnamed: 0      Zone           State         City  \
# 0             0  Northern           Delhi        Delhi
# 1             1  Northern           Delhi        Delhi
# 2             2  Northern           Delhi        Delhi
# 3             3  Northern           Delhi        Delhi
# 4             4  Northern           Delhi        Delhi
# ..          ...       ...             ...          ...
# 320         320   Western         Gujarat  Gandhinagar
# 321         321   Central   Uttar Pradesh         Agra
# 322         322   Central  Madhya Pradesh       Bhopal
# 323         323  Northern       Rajasthan       Jaipur
# 324         324  Northern       Rajasthan       Jaipur
#
#                              Name          Type Establishment Year  \
# 0                      India Gate  War Memorial               1921
# 1                  Humayun's Tomb          Tomb               1572
# 2               Akshardham Temple        Temple               2005
# ...

# %%
dataset.shape
# Out:
# (325, 16)

# %%
dataset['City'].value_counts()
# Out:
# City
# Delhi          16
# Goa            14
# Hyderabad      11
# Mumbai         10
# Kolkata        10
#                ..
# Neil Island     1
# Port Blair      1
# Bodh Gaya       1
# Kedarnath       1
# Cherrapunji     1
# Name: count, Length: 214, dtype: int64

# %%
len(dataset['City'].value_counts())
# Out:
# 214

# %%
#dataset['City'].value_counts().plot(kind='bar')
dataset['Zone'].value_counts().plot(kind='bar')
plt.title('Top Indian Places to Visit - Zone wise')
plt.xlabel('Zones in india')
plt.ylabel('Number of places')
plt.show()

# %%
dataset['State'].value_counts().plot(kind='bar')
plt.title('Top Indian places to visit - State wise')
plt.xlabel('States in India')
plt.ylabel('Number of places')
plt.show()
